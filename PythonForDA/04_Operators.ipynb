# %% [markdown]
# <a href="https://colab.research.google.com/github/AmitPrasad212003/Master-Data-Science-and-AI/blob/main/PythonForDA/04_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OPERATORS IN PYTHON
#
# ---
#
# ## 1️⃣ WHAT IS AN OPERATOR IN PYTHON?
#
# An **operator** defines how **objects interact** with each other.
#
# Internally, every operator maps to a **special method (magic method)** such as:
#
# | Operator | Method |
# | --- | --- |
# | `+` | `__add__()` |
# | `==` | `__eq__()` |
# | `<` | `__lt__()` |
# | `in` | `__contains__()` |
#
# 👉 Operators are **type-dependent**, not universal.
#
# ---
#
# ## 2️⃣ CLASSIFICATION OF OPERATORS (OVERVIEW)
#
# | Category | Purpose |
# | --- | --- |
# | Arithmetic | Mathematical operations |
# | Comparison | Value comparison |
# | Logical | Boolean logic |
# | Assignment | Variable binding |
# | Bitwise | Binary manipulation |
# | Membership | Containment testing |
# | Identity | Object identity |
# | Conditional | Inline decision |
#
# ---
#
# ## 3️⃣ ARITHMETIC OPERATORS
#
# ### Operators Table
#
# | Operator | Meaning | Advanced Behavior |
# | --- | --- | --- |
# | `+` | Addition | Overloaded for sequences |
# | `-` | Subtraction | Unary & binary |
# | `*` | Multiplication | Repetition for sequences |
# | `/` | Division | Always returns float |
# | `//` | Floor division | Floors toward −∞ |
# | `%` | Modulus | Result follows divisor sign |
# | `**` | Exponent | Right-associative |
#
# ---
#
# ### 🔹 EDGE CASES (Arithmetic)
#
# ### 1. Floor Division with Negatives
#
# ```python
# -5 // 2 # -3
#
# ```
#
# **Why:** Floor division rounds **down**, not toward zero.
#
# ---
#
# ### 2. Modulus with Negative Numbers
#
# ```python
# -5 % 2# 1
#
# ```
#
# **Rule:**
#
# ```
# (a // b) * b + (a % b) == a
#
# ```
#
# ---
#
# ### 3. Exponent Right-Associativity
#
# ```python
# 2 **3 **2# 512
#
# ```
#
# Equivalent to `2 ** (3 ** 2)`.
#
# ---
#
# ## 4️⃣ COMPARISON OPERATORS
#
# ### Operators Table
#
# | Operator | Meaning |
# | --- | --- |
# | `==` | Equal value |
# | `!=` | Not equal |
# | `<` `>` | Ordering |
# | `<=` `>=` | Inclusive ordering |
#
# ---
#
# ### 🔹 Chained Comparison (Optimization)
#
# ```python
# 1 < x <10
#
# ```
#
# - Evaluated left-to-right
# - Middle expression evaluated once
# - Faster and cleaner than `and`
#
# ---
#
# ### 🔹 EDGE CASE: Mixed Types (Python 3)
#
# ```python
# 1 < "1" # TypeError
#
# ```
#
# **Why:** Python 3 enforces type safety.
#
# ---
#
# ## 5️⃣ LOGICAL OPERATORS — SHORT-CIRCUIT BEHAVIOR
#
# ### Operators Table
#
# | Operator | Behavior |
# | --- | --- |
# | `and` | Returns first falsy value |
# | `or` | Returns first truthy value |
# | `not` | Boolean negation |
#
# ---
#
# ### 🔹 EDGE CASE: Return Value Is NOT Boolean
#
# ```python
# 0 and 10# 0
# 10 or 5# 10
#
# ```
#
# ✔ Logical operators return **operands**, not `True`/`False`.
#
# ---
#
# ### 🔹 Short-Circuit Evaluation
#
# ```python
# x != 0 and (10 / x)
#
# ```
#
# Second expression skipped if first is false.
#
# ---
#
# ## 6️⃣ ASSIGNMENT OPERATORS
#
# ### Operators Table
#
# | Operator | Effect |
# | --- | --- |
# | `=` | Binding |
# | `+=` | In-place or rebinding |
# | `*=` | Depends on mutability |
#
# ---
#
# ### 🔹 EDGE CASE: Mutable vs Immutable
#
# ```python
# a = [1,2]
# b = a
# a += [3]
#
# ```
#
# Both `a` and `b` change.
#
# ```python
# x =10
# x +=5
#
# ```
#
# Creates new object.
#
# ---
#
# ## 7️⃣ BITWISE OPERATORS
#
# ### Operators Table
#
# | Operator | Meaning |
# | --- | --- |
# | `&` | AND |
# | ` | ` |
# | `^` | XOR |
# | `~` | NOT |
# | `<<` | Left shift |
# | `>>` | Right shift |
#
# ---
#
# ### 🔹 EDGE CASE: Bitwise NOT
#
# ```python
# ~5 # -6
#
# ```
#
# **Why:** Two’s complement representation.
#
# ---
#
# ## 8️⃣ MEMBERSHIP OPERATORS (`in`, `not in`)
#
# ### Behavior Table
#
# | Type | Lookup Time |
# | --- | --- |
# | list | O(n) |
# | set | O(1) |
# | dict | O(1) |
#
# ---
#
# ### 🔹 EDGE CASE: `in` on Dictionary
#
# ```python
# "a" in {"a":1}# True
#
# ```
#
# Checks **keys only**, not values.
#
# ---
#
# ## 9️⃣ IDENTITY OPERATORS (`is`, `is not`)
#
# ### Meaning Table
#
# | Operator | Checks |
# | --- | --- |
# | `is` | Same object |
# | `==` | Same value |
#
# ---
#
# ### 🔹 EDGE CASE: Interning Illusion
#
# ```python
# a = 256
# b = 256
# a is b # True
#
# ```
#
# But:
#
# ```python
# x = 1000
# y = 1000
# x is y# False
#
# ```
#
# ✔ Never rely on `is` for value comparison.
#
# ---
#
# ## 🔟 CONDITIONAL (TERNARY) OPERATOR
#
# ```python
# result = "Pass" if marks >=40else"Fail"
#
# ```
#
# ### EDGE CASE
#
# Nested ternaries reduce readability.
#
# ---
#
# ## 1️⃣1️⃣ OPERATOR OVERLOADING
#
# Operators behave differently based on object type.
#
# ```python
# "Py" +"thon"
# [1] + [2]
#
# ```
#
# ✔ Controlled via magic methods.
#
# ---
#
# # ORDER OF OPERATOR PRECEDENCE (HIGH → LOW)
#
# | Level | Operators |
# | --- | --- |
# | 1 | `()` |
# | 2 | `**` |
# | 3 | `+x`, `-x`, `~x` |
# | 4 | `* / // %` |
# | 5 | `+ -` |
# | 6 | `<< >>` |
# | 7 | `&` |
# | 8 | `^` |
# | 9 | ` |
# | 10 | Comparisons |
# | 11 | `not` |
# | 12 | `and` |
# | 13 | `or` |
# | 14 | Assignment |
#
# ---
#
# ## 🔹 PRECEDENCE EDGE CASES
#
# ### Example 1
#
# ```python
# not True and False# False
#
# ```
#
# Evaluated as:
#
# ```python
# (not True) and False
#
# ```
#
# ---
#
# ### Example 2
#
# ```python
# 2 **3 **2# 512
#
# ```
#
# Right-associative exponentiation.
#
# ---
#
# ### Example 3
#
# ```python
# a = b = c = 10
#
# ```
#
# Assignment is right-associative.
# # HOW DATA TYPES CHANGE WITH OPERATORS IN PYTHON — AND WHY
#
# ---
#
# ## 1️⃣ CORE IDEA (MOST IMPORTANT)
#
# In Python:
#
# > Operators do not operate on variables — they operate on objects.
# >
# >
# > The **resulting data type** depends on:
# >
# > - The **types of operands**
# > - The **operator used**
# > - The **rules defined by Python’s type system**
# > - The **special methods (`__add__`, `__mul__`, etc.)**
#
# Variables only **rebind** to the new result object.
#
# ---
#
# ## 2️⃣ WHY DATA TYPE CHANGES HAPPEN
#
# ### Python follows these principles:
#
# 1. **Dynamic typing**
#     - Type is decided at runtime
# 2. **Strong typing**
#     - No unsafe implicit conversions
# 3. **Type promotion rules**
#     - Smaller / narrower types promoted to larger / more general types
# 4. **Operator overloading**
#     - Same operator behaves differently for different types
#
# ---
#
# ## 3️⃣ TYPE PROMOTION IN ARITHMETIC OPERATORS
#
# ### General Rule
#
# > When operands have different numeric types, Python promotes to the most general type.
# >
#
# ### Numeric Promotion Hierarchy
#
# ```
# bool →int →float → complex
#
# ```
#
# ---
#
# ### 📌 Examples
#
# ```python
# 5 +2.5
#
# ```
#
# **Result type:** `float`
#
# **Why:** `int` is promoted to `float`
#
# ---
#
# ```python
# True +10
#
# ```
#
# **Result type:** `int`
#
# **Why:** `bool` is a subclass of `int`
#
# ---
#
# ```python
# 5 +3j
#
# ```
#
# **Result type:** `complex`
#
# **Why:** `complex` is the highest numeric type
#
# ---
#
# ## 4️⃣ DIVISION OPERATOR (`/`) — FORCED TYPE CHANGE
#
# ```python
# 5 /2
#
# ```
#
# **Result type:** `float`
#
# ### Why?
#
# Python defines `/` as **true division**, always producing a floating-point result — even if operands are integers.
#
# This avoids ambiguity and increases mathematical correctness.
#
# ---
#
# ## 5️⃣ FLOOR DIVISION (`//`) — SUBTLE TYPE RULE
#
# | Operands | Result Type |
# | --- | --- |
# | `int // int` | `int` |
# | `int // float` | `float` |
#
# ```python
# 5 //2# int
# 5 //2.0# float
#
# ```
#
# ### Why?
#
# The presence of a float operand forces floating-point arithmetic.
#
# ---
#
# ## 6️⃣ MODULUS OPERATOR (`%`) — TYPE FOLLOWS OPERAND
#
# ```python
# 5 %2.0
#
# ```
#
# **Result type:** `float`
#
# ### Why?
#
# Modulo follows the **type of the divisor**, due to mathematical identity:
#
# ```
# (a// b) * b + (a % b) = a
#
# ```
#
# ---
#
# ## 7️⃣ EXPONENTIATION (`*`) — TYPE ESCALATION
#
# ```python
# 2 **3# int
# 2 **3.0# float
# 2 ** -1# float
#
# ```
#
# ### Why?
#
# - Negative exponent requires fractional result
# - Fractional math → float
#
# ---
#
# ## 8️⃣ STRING + OPERATOR — OPERATOR OVERLOADING
#
# ```python
# "Py" +"thon"
#
# ```
#
# **Result type:** `str`
#
# ### Why?
#
# The `+` operator is overloaded to mean **concatenation** for strings.
#
# ---
#
# ### ❌ Invalid Mixed Type
#
# ```python
# "Age: " +25
#
# ```
#
# **Why error?**
#
# Python does **not** auto-convert numbers to strings → strong typing.
#
# ---
#
# ## 9️⃣ MULTIPLICATION () — TYPE CONTROLLED BY LEFT OPERAND
#
# ```python
# "Hi" *3
#
# ```
#
# **Result type:** `str`
#
# ```python
# [1,2] *2
#
# ```
#
# **Result type:** `list`
#
# ### Why?
#
# Python defines `*` as **repetition** for sequences.
#
# ---
#
# ### ❌ Invalid Case
#
# ```python
# "Hi" *2.5
#
# ```
#
# **Why error?**
#
# Repetition count must be an integer.
#
# ---
#
# ## 🔟 COMPARISON OPERATORS — TYPE COLLAPSE TO BOOLEAN
#
# ```python
# 5 >3
#
# ```
#
# **Result type:** `bool`
#
# ### Why?
#
# Comparison operators always return a **truth value**, regardless of operand types.
#
# ---
#
# ## 1️⃣1️⃣ LOGICAL OPERATORS — SURPRISING TYPE PRESERVATION
#
# ```python
# 10and20
#
# ```
#
# **Result type:** `int`
#
# ```python
# 0or"Python"
#
# ```
#
# **Result type:** `str`
#
# ### Why?
#
# Logical operators:
#
# - Do **not** return `True` or `False`
# - Return one of the **original operands**
# - Based on truthiness
#
# ---
#
# ## 1️⃣2️⃣ ASSIGNMENT OPERATORS (`+=`, `=`) — MUTABILITY EFFECT
#
# ### Immutable Case
#
# ```python
# x =10
# x +=5
#
# ```
#
# **Type:** `int` (new object created)
#
# ---
#
# ### Mutable Case
#
# ```python
# lst = [1,2]
# lst += [3]
#
# ```
#
# **Type:** `list` (same object modified)
#
# ### Why?
#
# - Immutable → new object
# - Mutable → in-place modification
#
# ---
#
# ## 1️⃣3️⃣ BITWISE OPERATORS — TYPE PRESERVED
#
# ```python
# 5 &3
#
# ```
#
# **Result type:** `int`
#
# ### Why?
#
# Bitwise operators work at the **binary level**, only valid for integers.
#
# ---
#
# ## 1️⃣4️⃣ MEMBERSHIP OPERATORS — BOOLEAN OUTPUT
#
# ```python
# 2in [1,2,3]
#
# ```
#
# **Result type:** `bool`
#
# ### Why?
#
# Membership checks answer a yes/no question.
#
# ---
#
# ## 1️⃣5️⃣ IDENTITY OPERATORS — BOOLEAN OUTPUT
#
# ```python
# ais b
#
# ```
#
# **Result type:** `bool`
#
# ### Why?
#
# Identity checks memory location, not value.
#
# ---
#
# ## 1️⃣6️⃣ SUMMARY TABLE — OPERATOR VS TYPE CHANGE
#
# | Operator | Type Change Behavior | Reason |
# | --- | --- | --- |
# | `+ - *` | Promotes numeric types | Type hierarchy |
# | `/` | Always float | True division |
# | `//` | Depends on operands | Floor semantics |
# | `%` | Follows divisor | Mathematical identity |
# | `**` | Escalates type | Fractional result |
# | Comparison | Always bool | Logical result |
# | Logical | Returns operand | Short-circuit logic |
# | Assignment | Depends on mutability | Object model |
# | Bitwise | int only | Binary operations |

# %%
a=10
b=2

# %%
a=3
b=4
a**b
# Out:
# 81

# %%
a/b
# Out:
# 5.0

# %%
a-b
# Out:
# 8

# %%
a=50
b=8

# %%
a//b
# Out:
# 6

# %%
a//b --> Floor Division
Floor
Ceiling
# Out:
# 6

# %%
# Modulus/Reminder

a%b
# Out:
# 2

# %%
a=3
b=4
a**b
# Out:
# 81

# %%
# BODMAS

print((4*5)-9+6/7)
# Out:
# 11.857142857142858

# %%
(4*5)
# Out:
# 20

# %%
6/7
# Out:
# 0.8571428571428571

# %%
print(4+(8**2)-3**2%1)
# Out:
# 68

# %%
9%1
# Out:
# 0

# %%
print(4 % (1 + 9)**2 - 60 // (7 + 2))

# %%
# Out:
# 68

# %%
9%1
# Out:
# 0

# %%
60//7
# Out:
# 8

# %%
60%7
# Out:
# 4

# %%
3**3
# Out:
# 27

# %%
3**4
# Out:
# 81

# %%
floor: 8
ceiling: 9

# %%
2+5
# Out:
# 7

# %%
2-5
# Out:
# -3

# %%
2*5
# Out:
# 10

# %%
2/5
# Out:
# 0.4

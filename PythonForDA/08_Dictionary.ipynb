# %% [markdown]
# <a href="https://colab.research.google.com/github/AmitPrasad212003/Master-Data-Science-and-AI/blob/main/PythonForDA/08_Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1️⃣ What is a Dictionary?
#
# A **dictionary** is a **collection of key–value pairs**.
#
# Think of it like a **real dictionary**:
#
# | Word (Key) | Meaning (Value) |
# | --- | --- |
# | apple | a fruit |
# | python | programming language |
#
# ### Syntax
#
# ```python
# dict_name = {key: value}
#
# ```
#
# ### Example
#
# ```python
# student = {
# "name":"Rahul",
# "age":21,
# "marks":85
# }
#
# print(student)
#
# ```
#
# **Output**
#
# ```
# {'name':'Rahul','age': 21,'marks': 85}
#
# ```
#
# ---
#
# ## 2️⃣ Important Properties of Dictionary
#
# | Property | Explanation |
# | --- | --- |
# | Mutable | Can be changed |
# | Unordered (Old) | Before Python 3.7 |
# | Ordered | From Python 3.7+ |
# | Keys Unique | No duplicate keys |
# | Fast Lookup | O(1) average time |
#
# ---
#
# ## 3️⃣ Creating Dictionary (All Ways)
#
# ### 3.1 Empty Dictionary
#
# ```python
# d = {}
# print(type(d))
#
# ```
#
# **Output**
#
# ```
# <class'dict'>
#
# ```
#
# ⚠️ `{}` always creates a dictionary, not a set.
#
# ---
#
# ### 3.2 Using `dict()`
#
# ```python
# d =dict(name="Aman", age=20)
# print(d)
#
# ```
#
# ---
#
# ### 3.3 From List of Tuples
#
# ```python
# d =dict([("a",1), ("b",2)])
# print(d)
#
# ```
#
# ---
#
# ### 3.4 Dictionary Comprehension
#
# ```python
# squares = {x: x*xfor xinrange(5)}
# print(squares)
#
# ```
#
# **Output**
#
# ```
# {0:0,1:1,2:4,3:9,4:16}
#
# ```
#
# ---
#
# ## 4️⃣ Dictionary Keys (VERY IMPORTANT)
#
# ### ✅ Valid Keys
#
# - `int`
# - `float`
# - `str`
# - `tuple`
#
# ```python
# d = {(1,2):"tuple key"}
#
# ```
#
# ### ❌ Invalid Keys
#
# - list
# - set
# - dictionary
#
# ```python
# d = {[1,2]:"value"}# ❌ ERROR
#
# ```
#
# **Error**
#
# ```
# TypeError: unhashabletype:'list'
#
# ```
#
# ### WHY?
#
# Keys must be **hashable (immutable)** so Python can store them in a hash table.
#
# ---
#
# ## 5️⃣ Accessing Dictionary Values
#
# ### 5.1 Using `[]`
#
# ```python
# d = {"a":10,"b":20}
# print(d["a"])
#
# ```
#
# **Output**
#
# ```
# 10
#
# ```
#
# ⚠️ If key not found:
#
# ```python
# print(d["c"])
#
# ```
#
# **Error**
#
# ```
# KeyError
#
# ```
#
# ---
#
# ### 5.2 Using `get()` (SAFE)
#
# ```python
# print(d.get("c"))
# print(d.get("c",0))
#
# ```
#
# **Output**
#
# ```
# None
# 0
#
# ```
#
# ✔ Preferred when key may not exist.
#
# ---
#
# ## 6️⃣ Adding & Updating Elements
#
# ```python
# d = {"a":1}
# d["b"] =2# add
# d["a"] =10# update
#
# print(d)
#
# ```
#
# **Output**
#
# ```
# {'a':10,'b':2}
#
# ```
#
# ---
#
# ## 7️⃣ Removing Elements
#
# ### 7.1 `pop()`
#
# ```python
# d = {"a":1,"b":2}
# d.pop("a")
# print(d)
#
# ```
#
# ---
#
# ### 7.2 `del`
#
# ```python
# del d["b"]
#
# ```
#
# ⚠️ KeyError if missing.
#
# ---
#
# ### 7.3 `popitem()`
#
# ```python
# d = {"x":1,"y":2}
# d.popitem()
#
# ```
#
# Removes **last inserted item** (Python 3.7+).
#
# ---
#
# ## 8️⃣ Dictionary Methods (With Examples)
#
# ### `keys()`
#
# ```python
# print(d.keys())
#
# ```
#
# ### `values()`
#
# ```python
# print(d.values())
#
# ```
#
# ### `items()`
#
# ```python
# print(d.items())
#
# ```
#
# ---
#
# ## 9️⃣ Iterating Over Dictionary
#
# ### Keys
#
# ```python
# for keyin d:
# print(key)
#
# ```
#
# ### Key + Value
#
# ```python
# for k, vin d.items():
# print(k, v)
#
# ```
#
# ---
#
# ## 🔟 Dictionary Copy (IMPORTANT EDGE CASE)
#
# ### Shallow Copy
#
# ```python
# d1 = {"a": [1,2]}
# d2 = d1.copy()
#
# d2["a"].append(3)
# print(d1)
#
# ```
#
# **Output**
#
# ```
# {'a': [1,2,3]}
#
# ```
#
# ⚠️ Nested objects share memory.
#
# ---
#
# ### Deep Copy
#
# ```python
# import copy
# d2 = copy.deepcopy(d1)
#
# ```
#
# ---
#
# ## 1️⃣1️⃣ `setdefault()` (ADVANCED)
#
# ```python
# d = {}
# d.setdefault("a", []).append(1)
# print(d)
#
# ```
#
# **Output**
#
# ```
# {'a': [1]}
#
# ```
#
# ✔ Adds key if not present
#
# ⚠️ Modifies dictionary
#
# ---
#
# ## 1️⃣2️⃣ `defaultdict` (ADVANCED)
#
# ```python
# from collectionsimport defaultdict
#
# d = defaultdict(int)
# d["a"] +=1
# print(d)
#
# ```
#
# **Output**
#
# ```
# {'a':1}
#
# ```
#
# 🔥 No KeyError
#
# ---
#
# ## 1️⃣3️⃣ `Counter` (Frequency Counting)
#
# ```python
# from collectionsimport Counter
# print(Counter("banana"))
#
# ```
#
# **Output**
#
# ```
# {'a':3,'n':2,'b':1}
#
# ```
#
# ---
#
# ## 1️⃣4️⃣ Dictionary Internals (ADVANCED CONCEPT)
#
# ### How it Works
#
# - Uses **Hash Table**
# - Key → `hash()` → index
# - Collision handled internally
#
# ```python
# hash("a")
#
# ```
#
# ### Time Complexity
#
# | Operation | Time |
# | --- | --- |
# | Search | O(1) |
# | Insert | O(1) |
# | Delete | O(1) |
#
# Worst case → O(n) (rare)
#
# ---
#
# ## 1️⃣5️⃣ Dictionary Equality
#
# ```python
# {"a":1,"b":2} == {"b":2,"a":1}
#
# ```
#
# **Output**
#
# ```
# True
#
# ```
#
# Order does NOT matter.
#
# ---
#
# ## 1️⃣6️⃣ Merging Dictionaries
#
# ### Python 3.9+
#
# ```python
# d1 = {"a":1}
# d2 = {"b":2}
# print(d1 | d2)
#
# ```
#
# ---
#
# ## 1️⃣7️⃣ Common Mistakes (INTERVIEW EDGE CASES)
#
# ### ❌ Mutable Default Argument
#
# ```python
# deffun(d={}):
#     d["x"] =1
# return d
#
# ```
#
# ✔ Correct:
#
# ```python
# deffun(d=None):
# if disNone:
#         d = {}
#
# ```
#
# ---
#
# ### ❌ Changing Dict During Loop
#
# ```python
# for kin d:
#     d[k] =0# RuntimeError
#
# ```
#
# ---
#
# ## 1️⃣8️⃣ When to Use Dictionary
#
# ✔ Fast lookup
#
# ✔ Mapping relationships
#
# ✔ Counting frequency
#
# ✔ Caching
#
# ✔ JSON / API data
#
# ---
#
# ## 1️⃣9️⃣ Dictionary vs List vs Set
#
# | Feature | Dict | List | Set |
# | --- | --- | --- | --- |
# | Lookup | O(1) | O(n) | O(1) |
# | Order | Yes | Yes | No |
# | Duplicate | Keys ❌ | ✔ | ❌ |

# %%
# Creating a dictionary

d1 = {"India": "INR", "USA": "USD", "Hong Kong": "HKD"}
# Accessing value using keys

d1["India"]
# Out:
# 'INR'

# %%
# Replacing the value for a key in a dictionary

d1["India"] = "NEW"
d1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1303341798.py in <cell line: 0>()
#       1 # Replacing the value for a key in a dictionary
#       2
# ----> 3 d1["India"] = "NEW"
#       4 d1
#
# NameError: name 'd1' is not defined

# %%
d1["Japan"] = "YEN"

# %%
d1
# Out:
# {'India': 'YEN', 'USA': 'USD', 'Hong Kong': 'HKD', 'Japan': 'YEN'}

# %%
# Inserting a new key-value pair

d1["Japan"] = "YEN"

d1

# %%
select customer_id, customer_name, cust_type, x1, x2 from customer

# %%
delete customer where customer_id = '123'

# %%
d1
# Out:
# {'India': 'YEN', 'USA': 'USD', 'Hong Kong': 'HKD', 'Japan': 'YEN'}

# %%
# Deleting a key value pair

del d1["Japan"]

d1
# Out:
# {'India': 'YEN', 'USA': 'USD', 'Hong Kong': 'HKD'}

# %%
# Sorting a dictionary

sorted(d1)
# Out:
# ['Hong Kong', 'India', 'USA']

# %%
d1["India"] = "INR"

# %%
d1
# Out:
# {'India': 'INR', 'USA': 'USD', 'Hong Kong': 'HKD'}

# %%
# values() method

d1.values()
# Out:
# dict_values(['INR', 'USD', 'HKD'])

# %%
# keys() method

d1.keys()
# Out:
# dict_keys(['India', 'USA', 'Hong Kong'])

# %%
# get() method

d1.get('India')
# Out:
# 'INR'

# %%
# update() method

d1.update({"India": "Rs"})
d1["India"] = "Rs"

d1
# Out:
# {'India': 'Rs', 'USA': 'USD', 'Hong Kong': 'HKD'}

# %% [markdown]
# #### Practice Codes

# %% [markdown]
# ##### Question 1
# ##### Description
# Write code to fetch the profession of the employee with Employee id - 104 from an employee input given in the form of a dictionary where key represent employee id and values represent the name, age, and profession (in the same order).
#
# Sample input:
#
# Employee_data = { 101:['Shiva', 24, 'Content Strategist'] ,102:['Udit',25,'Content Strategist'], 103:['Sonam', 28,'Sr Manager'], 104:['Ansari',29,'Product Lead' ],105:['Huzefa',32,'Project Manager' ]}
#
# Sample output:
#
# 'Product Lead'
#
# Note: Assume that employee data would be available in the data provided to you

# %%
Employee_data = { 101:['Shiva', 24, 'Content Strategist'] ,102:['Udit',25,'Content Strategist'], 103:['Sonam', 28,'Sr Manager'], 104:['Ansari',29,'Product Lead' ],105:['Huzefa',32,'Project Manager' ]}

# %%
type(Employee_data)
# Out:
# dict

# %%
Employee_data
# Out:
# {101: ['Shiva', 24, 'Content Strategist'],
#  102: ['Udit', 25, 'Content Strategist'],
#  103: ['Sonam', 28, 'Sr Manager'],
#  104: ['Ansari', 29, 'Product Lead'],
#  105: ['Huzefa', 32, 'Project Manager']}

# %%
type(Employee_data.get(104))
# Out:
# list

# %%
list_2 = Employee_data.get(104)

# %%
list_2[2]
# Out:
# 'Product Lead'

# %%
Employee_data.get(104)[2]
# Out:
# 'Product Lead'

# %%
Employee_data = { 101:['Shiva', 24, 'Content Strategist'] ,102:['Udit',25,'Content Strategist'], 103:['Sonam', 28,'Sr Manager'], 104:['Ansari',29,'Product Lead' ],105:['Huzefa',32,'Project Manager' ]}

Employee_data.get(104)[2]
# Out:
# 'Product Lead'

# %% [markdown]
# ##### Question 2
#
# Suppose dict_1 = {"Python'':40, "R'':45}. What command should be used to delete the entry "R"?

# %%
dict_1 = {"Python":40, "R":45}

# %%
del dict_1["R"]

# %%
dict_1
# Out:
# {'Python': 40}

# %% [markdown]
# ##### Question 3
#
# d = {'Python':40, 'R':45}
#
# print(list(d.keys()))

# %%
d = {'Python':40, 'R':45}


print(list(d.keys()))
# Out:
# ['Python', 'R']

# %% [markdown]
# ##### Question 4
#
# ##### Description
# From a Dictionary input_dict={'Name': 'Monty', 'Profession': 'Singer' }, get the value of a key based on user input which is not a part of the dictionary, in such a way that Python doesn't hit an error. If the key does not exist in the dictionary, Python should return 'NA'.
#
# Sample Input:
#
# {'Name': 'Monty', 'Profession': 'Singer' }
#
#
#
# Sample Output:
#
# NA

# %%
input_dict={'Name': 'Monty', 'Profession': 'Singer' }

# %%
input_dict["Label"] = "NA"

# %%
input_dict["Label"]
# Out:
# 'NA'

# %%
input_dict = {'Name': 'Monty', 'Profession': 'Singer' }

# %%
input_dict.keys()
# Out:
# dict_keys(['Name', 'Profession'])

# %%
input_dict = {'Name': 'Monty', 'Profession': 'Singer' }

if "Label" in input_dict.keys():
    print(input_dict["Label"])
else:
    print("NA")

# %% [markdown]
# ##### Question 5
#
# - List of Values in a Dictionary.
#
# ##### Description
# Create a SORTED list of all values from the dictionary input_dict = {'Jack Dorsey' : 'Twitter' , 'Tim Cook' : 'Apple','Jeff Bezos' : 'Amazon' ,'Mukesh Ambani' : 'RJIO'}
#
#
#
# Sample Input:
#
# {'Jack Dorsey' : 'Twitter' , 'Tim Cook' : 'Apple','Jeff Bezos' : 'Amazon' ,'Mukesh Ambani' : 'RJIO'}
#
#
#
# Sample Output:
#
# ﻿['Amazon', 'Apple', 'RJIO', 'Twitter']

# %%
input_dict = {'Jack Dorsey' : 'Twitter' , 'Tim Cook' : 'Apple','Jeff Bezos' : 'Amazon' ,'Mukesh Ambani' : 'RJIO'}

# %%
sorted(input_dict.values())
# Out:
# ['Amazon', 'Apple', 'RJIO', 'Twitter']

# %%
input_dict = {'Jack Dorsey' : 'Twitter' , 'Tim Cook' : 'Apple','Jeff Bezos' : 'Amazon' ,'Mukesh Ambani' : 'RJIO'}

new_list = input_dict.values()

sorted(new_list)
# Out:
# ['Amazon', 'Apple', 'RJIO', 'Twitter']

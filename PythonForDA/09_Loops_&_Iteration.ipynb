# %% [markdown]
# <a href="https://colab.research.google.com/github/AmitPrasad212003/Master-Data-Science-and-AI/blob/main/PythonForDA/09_Loops_%26_Iteration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1️⃣ What EXACTLY is Iteration? (Deeper View)
#
# Iteration is **repeatedly requesting the “next value” from an iterable** until it is exhausted.
#
# Internally, Python does **NOT magically loop**. It uses:
#
# - `iter()` → creates an iterator
# - `next()` → fetches values one by one
# - `StopIteration` → ends the loop
#
# ---
#
# ## 2️⃣ `for` Loop — INTERNAL MECHANISM (VERY IMPORTANT)
#
# ### Code you write
#
# ```python
# for xin [10,20,30]:
# print(x)
#
# ```
#
# ### What Python actually does (conceptually)
#
# ```python
# _iter =iter([10,20,30])
#
# whileTrue:
# try:
#         x =next(_iter)
# print(x)
# except StopIteration:
# break
#
# ```
#
# ### Output
#
# ```
# 10
# 20
# 30
#
# ```
#
# 👉 **This explains many edge cases later.**
#
# ---
#
# ## 3️⃣ Iterables vs Iterators (CRITICAL CONCEPT)
#
# ### Iterable
#
# - Can be looped over
# - Has `__iter__()`
#
# Examples:
#
# ```python
# list,tuple, string,dict,set,range
#
# ```
#
# ### Iterator
#
# - Produces values one at a time
# - Has `__next__()`
# - Gets exhausted
#
# ---
#
# ### Example
#
# ```python
# nums = [1,2,3]
# it =iter(nums)
#
# print(next(it))
# print(next(it))
# print(next(it))
#
# ```
#
# **Output**
#
# ```
# 1
# 2
# 3
#
# ```
#
# Next call:
#
# ```python
# print(next(it))
#
# ```
#
# **Error**
#
# ```
# StopIteration
#
# ```
#
# ⚠️ Once exhausted, iterator is **dead**.
#
# ---
#
# ## 4️⃣ Looping Over Different Data Types (Edge Behavior)
#
# ---
#
# ### 4.1 List Iteration (Mutable)
#
# ```python
# lst = [1,2,3]
# for xin lst:
# print(x)
#
# ```
#
# ✔ Safe **if list is NOT modified**
#
# ---
#
# ### ❌ Modifying List While Iterating (BIG EDGE CASE)
#
# ```python
# lst = [1,2,3,4]
# for xin lst:
#     lst.remove(x)
# print(lst)
#
# ```
#
# **Output**
#
# ```
# [2, 3, 4]
# [2, 4]
#
# ```
#
# ❗ Why?
#
# - Iterator index moves forward
# - Elements shift left
# - Some elements skipped
#
# ✔ Correct way:
#
# ```python
# for xin lst[:]:
#     lst.remove(x)
#
# ```
#
# ---
#
# ### 4.2 String Iteration (Immutable)
#
# ```python
# s ="abc"
# for chin s:
# print(ch)
#
# ```
#
# ✔ Safe (strings cannot change)
#
# ---
#
# ### 4.3 Set Iteration (UNORDERED)
#
# ```python
# s = {1,2,3}
# for xin s:
# print(x)
#
# ```
#
# ⚠️ Output order is **not guaranteed**
#
# Never rely on order in sets.
#
# ---
#
# ### 4.4 Dictionary Iteration (INTERVIEW FAVORITE)
#
# ```python
# d = {"a":1,"b":2}
# for xin d:
# print(x)
#
# ```
#
# ✔ Iterates over **keys by default**
#
# ---
#
# ### Safe vs Unsafe Modification
#
# ❌ This causes RuntimeError:
#
# ```python
# for kin d:
#     d[k+"x"] =10
#
# ```
#
# **Error**
#
# ```
# RuntimeError: dictionary changed size during iteration
#
# ```
#
# ✔ Safe:
#
# ```python
# for kinlist(d):
#     d[k+"x"] =10
#
# ```
#
# ---
#
# ## 5️⃣ `range()` — Lazy Iteration (Advanced)
#
# ```python
# r =range(1_000_000_000)
#
# ```
#
# ✔ Uses **constant memory**
#
# ✔ Generates numbers **on demand**
#
# ---
#
# ### Edge Case: Step = 0
#
# ```python
# range(1,10,0)
#
# ```
#
# **Error**
#
# ```
# ValueError:range() arg3 must not be zero
#
# ```
#
# ---
#
# ### Reverse Range
#
# ```python
# for iinrange(5,0, -1):
# print(i)
#
# ```
#
# Output:
#
# ```
# 5 4 3 2 1
#
# ```
#
# ---
#
# ## 6️⃣ `while` Loop — Condition-Driven Iteration
#
# ### Basic Example
#
# ```python
# i =1
# while i <=3:
# print(i)
#     i +=1
#
# ```
#
# ---
#
# ### ❌ Infinite Loop Edge Case
#
# ```python
# i =1
# while i <5:
# print(i)
#
# ```
#
# ✔ Condition never changes → infinite loop
#
# ---
#
# ### ❌ Truthy/Falsy Trap
#
# ```python
# while []:
# print("Hi")
#
# ```
#
# No output because:
#
# - Empty list = False
#
# ---
#
# ## 7️⃣ Loop Control Statements (Deep Behavior)
#
# ---
#
# ### 7.1 `break` — Terminates Iterator
#
# ```python
# for iinrange(5):
# if i ==3:
# break
# print(i)
#
# ```
#
# Output:
#
# ```
# 0
# 1
# 2
#
# ```
#
# Iterator stops permanently.
#
# ---
#
# ### 7.2 `continue` — Skips Current Iteration
#
# ```python
# for iinrange(5):
# if i ==2:
# continue
# print(i)
#
# ```
#
# Output:
#
# ```
# 0
# 1
# 3
# 4
#
# ```
#
# ---
#
# ### 7.3 `pass` — Placeholder
#
# ```python
# for iinrange(3):
# pass
# print("Done")
#
# ```
#
# Output:
#
# ```
# Done
#
# ```
#
# ---
#
# ## 8️⃣ `for-else` & `while-else` (VERY IMPORTANT)
#
# ### Rule
#
# > else runs ONLY if loop finishes normally (NO break)
# >
#
# ---
#
# ### Example (No break)
#
# ```python
# for iinrange(3):
# print(i)
# else:
# print("Completed")
#
# ```
#
# Output:
#
# ```
# 0
# 1
# 2
# Completed
#
# ```
#
# ---
#
# ### Example (With break)
#
# ```python
# for iinrange(3):
# if i ==1:
# break
# else:
# print("Completed")
#
# ```
#
# Output:
#
# ```
# (noelse)
#
# ```
#
# ---
#
# ## 9️⃣ Nested Loops — Complexity Edge Case
#
# ```python
# for iinrange(3):
# for jinrange(3):
# print(i, j)
#
# ```
#
# ✔ Time Complexity: **O(n²)**
#
# ⚠️ Avoid deep nesting for large data.
#
# ---
#
# ## 🔟 `enumerate()` — Index Safety
#
# ❌ Bad practice:
#
# ```python
# for iinrange(len(lst)):
# print(i, lst[i])
#
# ```
#
# ✔ Correct:
#
# ```python
# for i, valinenumerate(lst):
# print(i, val)
#
# ```
#
# ---
#
# ## 1️⃣1️⃣ `zip()` — Shortest Iterable Wins (EDGE CASE)
#
# ```python
# a = [1,2,3]
# b = [10,20]
#
# for x, yinzip(a, b):
# print(x, y)
#
# ```
#
# Output:
#
# ```
# 1 10
# 2 20
#
# ```
#
# ⚠️ Stops at shortest iterable
#
# ---
#
# ## 1️⃣2️⃣ Comprehensions vs Loops (Performance)
#
# ```python
# squares = [x*xfor xinrange(5)]
#
# ```
#
# ✔ Faster
#
# ✔ Cleaner
#
# ✔ Uses optimized C loops internally
#
# ---
#
# ## 1️⃣3️⃣ Generator Loops (ADVANCED)
#
# ```python
# defgen():
# yield1
# yield2
#
# for xin gen():
# print(x)
#
# ```
#
# ✔ Lazy execution
#
# ✔ Memory efficient
#
# ---
#
# ## 1️⃣4️⃣ Common Interview Traps
#
# ---
#
# ### Trap 1: Reusing Iterator
#
# ```python
# it =iter([1,2,3])
#
# for xin it:
# print(x)
#
# for xin it:
# print(x)
#
# ```
#
# Output:
#
# ```
# 123
# (nooutput)
#
# ```
#
# Iterator exhausted.
#
# ---
#
# ### Trap 2: Loop Variable Leakage
#
# ```python
# for iinrange(3):
# pass
# print(i)
#
# ```
#
# Output:
#
# ```
# 2
#
# ```
#
# Loop variable survives outside loop.
#
# ---
#
# ## 1️⃣5️⃣ When to Use Which Loop
#
# | Scenario | Best Choice |
# | --- | --- |
# | Known range | `for` |
# | Condition based | `while` |
# | Index needed | `enumerate` |
# | Parallel loops | `zip` |
# | Large data | generator |

# %%
for i in range(3):
    pass
print(i)
# Out:
# 2

# %% [markdown]
# ### Loops

# %% [markdown]
# #### Check whether a number is even or odd

# %%
x = 101

if x % 2 == 0:
    print(x, "is an Even number")
else:
    print(x, "is an Odd number")
# Out:
# 101 is an Odd number

# %%
x = int(input("Enter your age: "))

if x % 2 == 0:
    print(x, "is an Even number")
else:
    print(x, "is an Odd number")
# Out:
# Enter your age: 21
# 21 is an Odd number

# %% [markdown]
# #### < 18 & > 50 are not allowed for the party. --> 18 or above and 50 and below are allowed for the party.

# %%
x = int(input("Enter your age: "))

if x < 18 or x > 50:
    print("Sorry!! You are not allowed for the party")
else:
    print("Welcome to the party")
# Out:
# Enter your age: 17
# Sorry!! You are not allowed for the party

# %% [markdown]
# #### Program which offers various discounts on purchase bills

# %%
shop_total = int(input("Input your billed amount: "))

if shop_total >=5000:
    print("You have won a voucher of Rs. 1000/-")
elif shop_total >=2500:
    print("You have won a voucher of Rs. 500/-")
else:
    print("OOPS!! No discount for you!!")
# Out:
# Input your billed amount: 1000
# OOPS!! No discount for you!!

# %% [markdown]
# ### Iteration

# %%
#Iterate over a list of integers

list_1 = [10,20,30,40,50]
for num in list_1:
    print(num)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
#Iterate over a String

str_1 = "Odisha"
for ch in str_1:
    print(ch)
# Out:
# O
# d
# i
# s
# h
# a

# %%
#Iterate over a dictionary

students_data = {1: ['Sam', 25], 2:['Sharma',28], 3:['Ravi',22], 4:['Sid',23], 5:['Varun',24]}

for key,val in students_data.items():
    print(val)
# Out:
# ['Sam', 25]
# ['Sharma', 28]
# ['Ravi', 22]
# ['Sid', 23]
# ['Varun', 24]

# %%
for key in students_data.keys():
    print(key)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
range(1,101)
# Out:
# range(1, 101)

# %%
#Iterate over a range of values

for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Comprehensions

# %%
list_1 = ["Automobiles", "Honda", "Benz", "Maruti", "Kia"]

list_2 = []

for i in list_1:
    list_2.append(i)

print(list_2)
# Out:
# ['Automobiles', 'Honda', 'Benz', 'Maruti', 'Kia']

# %%
list_1 = ["Automobiles", "Honda", "Benz", "Maruti", "Kia"]

list_2 = []

for i in list_1:
    list_2.append(len(i))

print(list_2)
# Out:
# [11, 5, 4, 6, 3]

# %%
list_1 = ["Automobiles", "Honda", "Benz", "Maruti", "Kia"]

list_2 = [len(i) for i in list_1]

print(list_2)
# Out:
# [11, 5, 4, 6, 3]

# %%
list_1 = ["Automobiles", "Honda", "Benz", "Maruti", "Kia"]

d = {i: len(i) for i in list_1}

d
# Out:
# {'Automobiles': 11, 'Honda': 5, 'Benz': 4, 'Maruti': 6, 'Kia': 3}
